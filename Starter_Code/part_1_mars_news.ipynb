# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 1: Scrape Titles and Preview Text from Mars News

# %%
# Import Splinter and BeautifulSoup
import json
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Step 1: Visit the Website
#
# 1. Use automated browsing to visit the [Mars NASA news site](https://redplanetscience.com). Inspect the page to identify which elements to scrape.
#
#       > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools.

# %%
# Visit the Mars NASA news site: https://redplanetscience.com
url = 'https://redplanetscience.com'
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Website
#
# Create a Beautiful Soup object and use it to extract text elements from the website.

# %%
# Create a Beautiful Soup object
html = browser.html
news_soup = soup(html, 'html.parser')
slide_elem = news_soup.select_one('div.list_text')

# %%
# Extract all the text elements
title_elem = slide_elem.find('div', class_='content_title')
print(title_elem.text)
# Out:
# NASA's Perseverance Rover Is Midway to Mars

# %%
print(news_soup.get_text())
# Out:
# News - Mars Exploration Program
#
#
#
#
#
#
#
# MARS Planet Science
# Exploration Program
#
#
#
#
#
#
#
# The Red Planet
#
#
# The Program
#
#
# News & Events
#
#
# Multimedia
#
#
# Missions
#
#
# More
#
#
#
#
#
#
#
#
#
#
# News
#
#
#
#
#
#
#
#
# Latest
# 20202019
#
#
#
# All Categories
# Feature StoriesPress ReleasesStatus Reports
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# December 18, 2022
# NASA's Perseverance Rover Is Midway to Mars
# Sometimes half measures can be a good thing – especially on a journey this long. The agency's latest rover only has about 146 million miles left to reach its destination.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# December 17, 2022
# NASA's Mars Perseverance Rover Passes Flight Readiness Review
# ​The agency's Mars 2020 mission has one more big prelaunch review – the Launch Readiness Review, on July 27.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# December 17, 2022
# NASA's MAVEN Maps Winds in the Martian Upper Atmosphere that Mirror the Terrain Below and Gives Clues to Martian Climate
# Researchers have created the first map of wind circulation in the upper atmosphere of a planet besides Earth, using data from NASA’s MAVEN spacecraft that were collected during the last two years.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# December 16, 2022
# Screening Soon: 'The Pathfinders' Trains Lens on Mars
# With the Mars 2020 mission ramping up, the documentary — the first of four about past JPL missions to the Red Planet to be shown at Caltech — tells a gripping backstory.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# December 9, 2022
# A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes
# Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# December 4, 2022
# NASA's Treasure Map for Water Ice on Mars
# A new study identifies frozen water just below the Martian surface, where astronauts could easily dig it up.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# December 4, 2022
# NASA's Mars 2020 Rover Completes Its First Drive
# In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# December 3, 2022
# NASA Moves Forward With Campaign to Return Mars Samples to Earth
# During this next phase, the program will mature critical technologies and make critical design decisions as well as assess industry partnerships.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# December 3, 2022
# NASA Wins Two Emmy Awards for Interactive Mission Coverage
# NASA-JPL's coverage of the Mars InSight landing earns one of the two wins, making this the NASA center's second Emmy.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# December 1, 2022
# NASA Invites Students to Name Mars 2020 Rover
# Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# November 29, 2022
# NASA's New Mars Rover Will Use X-Rays to Hunt Fossils
# PIXL, an instrument on the end of the Perseverance rover's arm, will search for chemical fingerprints left by ancient microbes.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# November 22, 2022
# HiRISE Views NASA's InSight and Curiosity on Mars
# New images taken from space offer the clearest orbital glimpse yet of InSight as well as a view of Curiosity rolling along.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# November 20, 2022
# What's Mars Solar Conjunction, and Why Does It Matter?
# NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# November 18, 2022
# Heat and Dust Help Launch Martian Water Into Space, Scientists Find
# Scientists using an instrument aboard NASA’s Mars Atmosphere and Volatile EvolutioN, or MAVEN, spacecraft have discovered that water vapor near the surface of the Red Planet is lofted higher into the atmosphere than anyone expected was possible.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# November 17, 2022
# NASA, ULA Launch Mars 2020 Perseverance Rover Mission to Red Planet
# The agency's Mars 2020 mission is on its way. It will land at Jezero Crater in about seven months, on Feb. 18, 2021.
#
#
#
#
#
#
# More
#
#
#
#
#
# You Might Also Like
#
#
#
#
#
#
#
#
#
#
#
# NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities
#
#
#
#
#
#
#
# The Launch Is Approaching for NASA's Next Mars Rover, Perseverance
#
#
#
#
#
#
#
# NASA to Hold Mars 2020 Perseverance Rover Launch Briefing
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
# With supporting text below as a natural lead-in to additional content.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Red Planet
#
# Dashboard
# Science Goals
# The Planet
#
#
#
# The Program
#
# Mission Statement
# About the Program
# Organization Why Mars?
#
#
#
# Multimedia
#
# Images
# Videos
# More Resources
#
#
#
# Missions
#
# Past
# Present
# Future

# %%
news_p = slide_elem.find('div', class_='article_teaser_body').text
news_p
# Out:
# "A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft."

# %%
title = news_soup.find_all('div', class_='content_title')
for news in title:
    print (news.text)
# Out:
# NASA's Mars 2020 Rover Tests Descent-Stage Separation
# Alabama High School Student Names NASA's Mars Helicopter
# NASA's Mars Rover Drivers Need Your Help
# NASA's Curiosity Rover Finds an Ancient Oasis on Mars
# 5 Hidden Gems Are Riding Aboard NASA's Perseverance Rover
# NASA's Briefcase-Size MarCO Satellite Picks Up Honors
# NASA's Perseverance Rover Is Midway to Mars
# NASA Wins 4 Webbys, 4 People's Voice Awards
# NASA's Mars 2020 Will Hunt for Microscopic Fossils
# Air Deliveries Bring NASA's Perseverance Mars Rover Closer to Launch
# Naming a NASA Mars Rover Can Change Your Life
# Mars InSight Lander to Push on Top of the 'Mole'
# NASA Moves Forward With Campaign to Return Mars Samples to Earth
# NASA Perseverance Mars Rover Scientists Train in the Nevada Desert
# Global Storms on Mars Launch Dust Towers Into the Sky

# %%
preview = news_soup.find_all('div', class_='article_teaser_body')
for news in preview:
    print(news.text)
# Out:
# A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft.
# Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.
# Using an online tool to label Martian terrain types, you can train an artificial intelligence algorithm that could improve the way engineers guide the Curiosity rover.
# New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# The symbols, mottos, and small objects added to the agency's newest Mars rover serve a variety of purposes, from functional to decorative.
# The twin spacecraft, the first of their kind to fly into deep space, earn a Laureate from Aviation Week & Space Technology.
# Sometimes half measures can be a good thing – especially on a journey this long. The agency's latest rover only has about 146 million miles left to reach its destination.
# Winners include the JPL-managed "Send Your Name to Mars" campaign, NASA's Global Climate Change website and Solar System Interactive.
# A new paper identifies a ring of minerals at the rover's landing site that are ideal for fossilizing microbial life.
# A NASA Wallops Flight Facility cargo plane transported more than two tons of equipment — including the rover's sample collection tubes — to Florida for this summer's liftoff.
# Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# Engineers have a plan for pushing down on the heat probe, which has been stuck at the Martian surface for a year.
# During this next phase, the program will mature critical technologies and make critical design decisions as well as assess industry partnerships.
# Team members searched for signs of ancient microscopic life there, just as NASA's latest rover will on the Red Planet next year.
# A Mars Dust Tower Stands Out Dust storms are common on Mars. But every decade or so, something unpredictable happens: a series of runaway storms break out, covering the entire planet in a dusty haze.

# %% [markdown]
# ### Step 3: Store the Results
#
# Extract the titles and preview text of the news articles that you scraped. Store the scraping results in Python data structures as follows:
#
# * Store each title-and-preview pair in a Python dictionary. And, give each dictionary two keys: `title` and `preview`. An example is the following:
#
#   ```python
#   {'title': "Mars Rover Begins Mission!",
#         'preview': "NASA's Mars Rover begins a multiyear mission to collect data about the little-explored planet."}
#   ```
#
# * Store all the dictionaries in a Python list.
#
# * Print the list in your notebook.

# %%
# Create an empty list to store the dictionaries
all_news = []

# %%
# Loop through the text elements
# Extract the title and preview text from the elements
# Store each title and preview pair in a dictionary
# Add the dictionary to the list
list_text = news_soup.find_all('div', class_='list_text')
for news in list_text:
    title = news.find('div', class_='content_title')
    preview = news.find('div', class_='article_teaser_body')
    all_news.append({
        "title":title.text,
        "preview":preview.text
    })
#     print("-"*64)
#     print (title.text)
#     print(preview.text)

# %%
# Print the list to confirm success
print (all_news)
# Out:
# ----------------------------------------------------------------
# [{'title': "NASA's Mars 2020 Rover Tests Descent-Stage Separation", 'preview': "A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft."}, {'title': "Alabama High School Student Names NASA's Mars Helicopter", 'preview': "Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet."}, {'title': "NASA's Mars Rover Drivers Need Your Help", 'preview': 'Using an online tool to label Martian terrain types, you can train an artificial intelligence algorithm that could improve the way engineers guide the Curiosity rover.'}, {'title': "NASA's Curiosity Rover Finds an Ancient Oasis on Mars", 'preview': "New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate."}, {'title': "5 Hidden Gems Are Riding Aboard NASA's Perseverance Rover", 'preview': "The symbols, mottos, and small objects added to the agency's newest Mars rover serve a variety of purposes, from functional to decorative."}, {'title': "NASA's Briefcase-Size MarCO Satellite Picks Up Honors", 'preview': 'The twin spacecraft, the first of their kind to fly into deep space, earn a Laureate from Aviation Week & Space Technology.'}, {'title': "NASA's Perseverance Rover Is Midway to Mars ", 'preview': "Sometimes half measures can be a good thing – especially on a journey this long. The agency's latest rover only has about 146 million miles left to reach its destination."}, {'title': "NASA Wins 4 Webbys, 4 People's Voice Awards", 'preview': 'Winners include the JPL-managed "Send Your Name to Mars" campaign, NASA\'s Global Climate Change website and Solar System Interactive.'}, {'title': "NASA's Mars 2020 Will Hunt for Microscopic Fossils", 'preview': "A new paper identifies a ring of minerals at the rover's landing site that are ideal for fossilizing microbial life."}, {'title': "Air Deliveries Bring NASA's Perseverance Mars Rover Closer to Launch", 'preview': "A NASA Wallops Flight Facility cargo plane transported more than two tons of equipment — including the rover's sample collection tubes — to Florida for this summer's liftoff."}, {'title': 'Naming a NASA Mars Rover Can Change Your Life', 'preview': 'Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.'}, {'title': "Mars InSight Lander to Push on Top of the 'Mole'", 'preview': 'Engineers have a plan for pushing down on the heat probe, which has been stuck at the Martian surface for a year.'}, {'title': 'NASA Moves Forward With Campaign to Return Mars Samples to Earth', 'preview': 'During this next phase, the program will mature critical technologies and make critical design decisions as well as assess industry partnerships.'}, {'title': 'NASA Perseverance Mars Rover Scientists Train in the Nevada Desert', 'preview': "Team members searched for signs of ancient microscopic life there, just as NASA's latest rover will on the Red Planet next year."}, {'title': 'Global Storms on Mars Launch Dust Towers Into the Sky', 'preview': 'A Mars Dust Tower Stands Out Dust storms are common on Mars. But every decade or so, something unpredictable happens: a series of runaway storms break out, covering the entire planet in a dusty haze.'}, {'title': "NASA's Mars 2020 Rover Tests Descent-Stage Separation", 'preview': "A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft."}, {'title': "Alabama High School Student Names NASA's Mars Helicopter", 'preview': "Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet."}, {'title': "NASA's Mars Rover Drivers Need Your Help", 'preview':  ...

# %% [markdown]
# ### (Optional) Step 4: Export the Data
#
# Optionally, store the scraped data in a file or database (to ease sharing the data with others). To do so, export the scraped data to either a JSON file or a MongoDB database.

# %%
# Export data to JSON
json_mars = json.dumps(all_news)
df=pd.read_json(json_mars)
df.to_csv('mars.csv',index=False)
df
# Out:
#                                                 title  \
# 0   NASA's Mars 2020 Rover Tests Descent-Stage Sep...
# 1   Alabama High School Student Names NASA's Mars ...
# 2            NASA's Mars Rover Drivers Need Your Help
# 3   NASA's Curiosity Rover Finds an Ancient Oasis ...
# 4   5 Hidden Gems Are Riding Aboard NASA's Perseve...
# 5   NASA's Briefcase-Size MarCO Satellite Picks Up...
# 6        NASA's Perseverance Rover Is Midway to Mars
# 7         NASA Wins 4 Webbys, 4 People's Voice Awards
# 8   NASA's Mars 2020 Will Hunt for Microscopic Fos...
# 9   Air Deliveries Bring NASA's Perseverance Mars ...
# 10      Naming a NASA Mars Rover Can Change Your Life
# 11   Mars InSight Lander to Push on Top of the 'Mole'
# 12  NASA Moves Forward With Campaign to Return Mar...
# 13  NASA Perseverance Mars Rover Scientists Train ...
# 14  Global Storms on Mars Launch Dust Towers Into ...
# 15  NASA's Mars 2020 Rover Tests Descent-Stage Sep...
# 16  Alabama High School Student Names NASA's Mars ...
# 17           NASA's Mars Rover Drivers Need Your Help
# 18  NASA's Curiosity Rover Finds an Ancient Oasis ...
# 19  5 Hidden Gems Are Riding Aboard NASA's Perseve...
# 20  NASA's Briefcase-Size MarCO Satellite Picks Up...
# 21       NASA's Perseverance Rover Is Midway to Mars
# 22        NASA Wins 4 Webbys, 4 People's Voice Awards
# 23  NASA's Mars 2020 Will Hunt for Microscopic Fos...
# 24  Air Deliveries Bring NASA's Perseverance Mars ...
# 25      Naming a NASA Mars Rover Can Change Your Life
# 26   Mars InSight Lander to Push on Top of the 'Mole'
# 27  NASA Moves Forward With Campaign to Return Mar...
# 28  NASA Perseverance Mars Rover Scientists Train ...
# 29  Global Storms on Mars Launch Dust Towers Into ...
#
#                                               preview
# 0   A crane lifts the rocket-powered descent stage...
# 1   Vaneeza Rupani's essay was chosen as the name ...
# 2   Using an online tool to label Martian terrain ...
# 3   New evidence suggests salty, shallow ponds onc...
# 4   The symbols, mottos, and small objects added t...
# 5   The twin spacecraft, the first of their kind t...
# 6   Sometimes half measures can be a good thing – ...
# 7   Winners include the JPL-managed "Send Your Nam...
# 8   A new paper identifies a ring of minerals at t...
# 9   A NASA Wallops Flight Facility cargo plane tra...
# 10  Want to name the robotic scientist NASA is sen...
# 11  Engineers have a plan for pushing down on the ...
# 12  During this next phase, the program will matur...
# 13  Team members searched for signs of ancient mic...
# 14  A Mars Dust Tower Stands Out Dust storms are c...
# 15  A crane lifts the rocket-powered descent stage...
# 16  Vaneeza Rupani's essay was chosen as the name ...
# 17  Using an online tool to label Martian terrain ...
# 18  New evidence suggests salty, shallow ponds onc...
# 19  The symbols, mottos, and small objects added t...
# 20  The twin spacecraft, the first of their kind t...
# 21  Sometimes half measures can be a good thing – ...
# 22  Winners include the JPL-managed "Send Your Nam...
# 23  A new paper identifies a ring of minerals at t...
# 24  A NASA Wallops Flight Facility cargo plane tra...
# 25  Want to name the robotic scientist NASA is sen...
# 26  Engineers have a plan for pushing down on the ...
# 27  During this next phase, the program will matur...
# 28  Team members searched for signs of ancient mic...
# 29  A Mars Dust Tower Stands Out Dust storms are c...

# %%
# Export data to MongoDB

# %%
# Quit browser 
browser.quit()
